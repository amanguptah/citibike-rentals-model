# %% [markdown]
# # Data Extraction

# %% [markdown]
# ## Downloading NYC Citi Bike Rental Data

# %%
import requests
import os
from xml.etree import ElementTree as ET

bucket_url = "https://s3.amazonaws.com/tripdata"

response = requests.get(bucket_url)
response_text = response.text

root = ET.fromstring(response_text)

namespace = {'s3': 'http://s3.amazonaws.com/doc/2006-03-01/'}

zip_links = [bucket_url + '/' + key.text for key in root.findall('s3:Contents/s3:Key', namespace) if key.text.endswith('.zip')]

os.makedirs('/content/tripdata_zips', exist_ok=True)

for i, link in enumerate(zip_links):
    if i >= 4:
        break

    zip_filename = os.path.join('/content/tripdata_zips', os.path.basename(link))

    print(f"Downloading {zip_filename} ...")

    with requests.get(link, stream=True) as r:
        r.raise_for_status()
        with open(zip_filename, 'wb') as f:
            for chunk in r.iter_content(chunk_size=8192):
                f.write(chunk)

print("Download completed.")
# Out:
# Downloading /content/tripdata_zips/2013-citibike-tripdata.zip ...
# Downloading /content/tripdata_zips/2014-citibike-tripdata.zip ...
# Downloading /content/tripdata_zips/2015-citibike-tripdata.zip ...
# Downloading /content/tripdata_zips/2016-citibike-tripdata.zip ...
# Download completed.

# %% [markdown]
# ## Import data to Pandas Dataframe and Pickle

# %%
import zipfile
import os
import pandas as pd

# Path where the ZIP files are stored
zip_folder = '/content/tripdata_zips/'

# Path for debugging and working datasets
debugging_folder = '/content/debugging_dataset/'
working_folder = '/content/working_dataset/'
debugging_pickle_paths = []
working_pickle_paths = []

# Create directories if they don't exist
os.makedirs(debugging_folder, exist_ok=True)
os.makedirs(working_folder, exist_ok=True)

# Define the first year of data to go into debugging
first_year = None

# Loop over each ZIP file in the folder
for i, zip_file in enumerate(os.listdir(zip_folder)):

    if zip_file.endswith(".zip"):
        # Open the ZIP file
        with zipfile.ZipFile(os.path.join(zip_folder, zip_file), 'r') as z:
            # Loop through each file in the ZIP archive
            print(f"Processing {zip_file} ... {z.namelist()}")
            for file_name in z.namelist():
                # Check if it's a CSV file (regardless of folder structure)
                if file_name.endswith(".csv") and not file_name.startswith("__MACOSX"):
                    print(f"Extracting and reading {file_name} from {zip_file}...")
                    try:
                        with z.open(file_name) as f:

                            df = pd.read_csv(f, encoding='utf-8')

                            df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

                            if 'starttime' in df.columns:
                                df['starttime'] = pd.to_datetime(df['starttime'], errors='coerce')
                            if 'stoptime' in df.columns:
                                df['stoptime'] = pd.to_datetime(df['stoptime'], errors='coerce')

                            base_name = os.path.basename(file_name)
                            year = base_name[0:4]
                            month = base_name[4:6]

                            if first_year is None:
                                first_year = year

                            if year == first_year:
                                pickle_filename = os.path.join(debugging_folder, f"{year}-{month}.pkl")
                                debugging_pickle_paths.append(pickle_filename)
                            else:
                                pickle_filename = os.path.join(working_folder, f"{year}-{month}.pkl")
                                working_pickle_paths.append(pickle_filename)

                            df.to_pickle(pickle_filename)
                            print(f"Saved {file_name} to {pickle_filename}")

                    except UnicodeDecodeError:
                        print(f"Failed to decode {file_name} with utf-8, trying ISO-8859-1...")
# Out:
# Processing 2014-citibike-tripdata.zip ... ['2014-citibike-tripdata/', '2014-citibike-tripdata/4_April/', '2014-citibike-tripdata/12_December/', '2014-citibike-tripdata/.DS_Store', '__MACOSX/2014-citibike-tripdata/._.DS_Store', '2014-citibike-tripdata/11_November/', '2014-citibike-tripdata/7_July/', '2014-citibike-tripdata/10_October/', '2014-citibike-tripdata/9_September/', '2014-citibike-tripdata/8_August/', '2014-citibike-tripdata/6_June/', '2014-citibike-tripdata/3_March/', '2014-citibike-tripdata/1_January/', '2014-citibike-tripdata/2_February/', '2014-citibike-tripdata/5_May/', '2014-citibike-tripdata/4_April/201404-citibike-tripdata_1.csv', '2014-citibike-tripdata/12_December/201412-citibike-tripdata_1.csv', '2014-citibike-tripdata/11_November/201411-citibike-tripdata_1.csv', '__MACOSX/2014-citibike-tripdata/11_November/._201411-citibike-tripdata_1.csv', '2014-citibike-tripdata/7_July/201407-citibike-tripdata_1.csv', '2014-citibike-tripdata/10_October/201410-citibike-tripdata_1.csv', '2014-citibike-tripdata/9_September/201409-citibike-tripdata_1.csv', '2014-citibike-tripdata/8_August/201408-citibike-tripdata_1.csv', '2014-citibike-tripdata/6_June/201406-citibike-tripdata_1.csv', '2014-citibike-tripdata/3_March/201403-citibike-tripdata_1.csv', '2014-citibike-tripdata/1_January/201401-citibike-tripdata_1.csv', '2014-citibike-tripdata/2_February/201402-citibike-tripdata_1.csv', '2014-citibike-tripdata/5_May/201405-citibike-tripdata_1.csv']
# Extracting and reading 2014-citibike-tripdata/4_April/201404-citibike-tripdata_1.csv from 2014-citibike-tripdata.zip...
# Saved 2014-citibike-tripdata/4_April/201404-citibike-tripdata_1.csv to /content/debugging_dataset/2014-04.pkl
# Extracting and reading 2014-citibike-tripdata/12_December/201412-citibike-tripdata_1.csv from 2014-citibike-tripdata.zip...
# Saved 2014-citibike-tripdata/12_December/201412-citibike-tripdata_1.csv to /content/debugging_dataset/2014-12.pkl
# Extracting and reading 2014-citibike-tripdata/11_November/201411-citibike-tripdata_1.csv from 2014-citibike-tripdata.zip...
# Saved 2014-citibike-tripdata/11_November/201411-citibike-tripdata_1.csv to /content/debugging_dataset/2014-11.pkl
# Extracting and reading 2014-citibike-tripdata/7_July/201407-citibike-tripdata_1.csv from 2014-citibike-tripdata.zip...
# Saved 2014-citibike-tripdata/7_July/201407-citibike-tripdata_1.csv to /content/debugging_dataset/2014-07.pkl
# Extracting and reading 2014-citibike-tripdata/10_October/201410-citibike-tripdata_1.csv from 2014-citibike-tripdata.zip...
# Saved 2014-citibike-tripdata/10_October/201410-citibike-tripdata_1.csv to /content/debugging_dataset/2014-10.pkl
# Extracting and reading 2014-citibike-tripdata/9_September/201409-citibike-tripdata_1.csv from 2014-citibike-tripdata.zip...
# Saved 2014-citibike-tripdata/9_September/201409-citibike-tripdata_1.csv to /content/debugging_dataset/2014-09.pkl
# Extracting and reading 2014-citibike-tripdata/8_August/201408-citibike-tripdata_1.csv from 2014-citibike-tripdata.zip...
# Saved 2014-citibike-tripdata/8_August/201408-citibike-tripdata_1.csv to /content/debugging_dataset/2014-08.pkl
# Extracting and reading 2014-citibike-tripdata/6_June/201406-citibike-tripdata_1.csv from 2014-citibike-tripdata.zip...
# Saved 2014-citibike-tripdata/6_June/201406-citibike-tripdata_1.csv to /content/debugging_dataset/2014-06.pkl
# Extracting and reading 2014-citibike-tripdata/3_March/201403-citibike-tripdata_1.csv from 2014-citibike-tripdata.zip...
# Saved 2014-citibike-tripdata/3_March/201403-citibike-tripdata_1.csv to /content/debugging_dataset/2014-03.pkl
# Extracting and reading 2014-citibike-tripdata/1_January/201401-citibike-tripdata_1.csv from 2014-citibike-tripdata.zip...
# Saved 2014-citibike-tripdata/1_January/201401-citibike-tripdata_1.csv to /content/debugging_dataset/2014-01.pkl
# Extracting and reading 2014-citibike-tripdata/2_February/201402-citibike-tripdata_1.csv from 2014-citibike-tripdata.zip...
# Saved 2014-citibike-tripdata/2_February/201402-citibike-tripdata_1.csv to /content/debugging_dataset/2014-02.pkl
# Extracting and reading 2014-citibike-tripdata/5_May/201405-citibike-tripdata_1.csv from 2014-citibike-tripdata.zip...
# Saved 2014-citibike-tripdata/5_May/201405-citibike-tripdata_1.csv to /content/debugging_dataset/2014-05.pkl
# Processing 2016-citibike-tripdata.zip ... ['2016-citibike-tripdata/', '2016-citibike-tripdata/4_April/', '2016-citibike-tripdata/12_December/', '2016-citibike-tripdata/.DS_Store', '__MACOSX/2016-citibike-tripdata/._.DS_Store', '2016-citibike-tripdata/11_November/', '2016-citibike-tripdata/7_July/', '2016-citibike-tripdata/10_October/', '2016-citibike-tripdata/9_September/', '2016-citibike-tripdata/8_August/', '2016-citibike-tripdata/6_June/', '2016-citibike-tripdata/3_March/', '2016-citibike-tripdata/1_January/', '2016-citibike-tripdata/2_February/', '2016-citibike-tripdata/5_May/', '2016-citibike-tripdata/4_April/201604-citibike-tripdata_1.csv', '2016-citibike-tripdata/4_April/201604-citibike-tripdata_2.csv', '2016-citibike-tripdata/12_December/201612-citibike-tripdata_1.csv', '2016-citibike-tripdata/11_November/201611-citibike-tripdata_2.csv', '2016-citibike-tripdata/11_November/201611-citibike-tripdata_1.csv', '2016-citibike-tripdata/7_July/201607-citibike-tripdata_2.csv', '2016-citibike-tripdata/7_July/201607-citibike-tripdata_1.csv', '2016-citibike-tripdata/10_October/201610-citibike-tripdata_1.csv', '2016-citibike-tripdata/10_October/201610-citibike-tripdata_2.csv', '2016-citibike-tripdata/9_September/201609-citibike-tripdata_1.csv', '2016-citibike-tripdata/9_September/201609-citibike-tripdata_2.csv', '2016-citibike-tripdata/8_August/201608-citibike-tripdata_2.csv', '2016-citibike-tripdata/8_August/201608-citibike-tripdata_1.csv', '2016-citibike-tripdata/6_June/201606-citibike-tripdata_1.csv', '2016-citibike-tripdata/6_June/201606-citibike-tripdata_2.csv', '2016-citibike-tripdata/3_March/201603-citibike-tripdata_1.csv', '2016-citibike-tripdata/1_January/201601-citibike-tripdata_1.csv', '2016-citibike-tripdata/2_February/201602-citibike-tripdata_1.csv', '2016-citibike-tripdata/5_May/201605-citibike-tripdata_2.csv', '2016-citibike-tripdata/5_May/201605-citibike-tripdata_1.csv']
# Extracting and reading 2016-citibike-tripdata/4_April/201604-citibike-tripdata_1.csv from 2016-citibike-tripdata.zip...
# Saved 2016-citibike-tripdata/4_April/201604-citibike-tripdata_1.csv to /content/working_dataset/2016-04.pkl
# Extracting and reading 2016-citibike-tripdata/4_April/201604-citibike-tripdata_2.csv from 2016-citibike-tripdata.zip...
# Saved 2016-citibike-tripdata/4_April/201604-citibike-tripdata_2.csv to /content/working_dataset/2016-04.pkl
# Extracting and reading 2016-citibike-tripdata/12_December/201612-citibike-tripdata_1.csv from 2016-citibike-tripdata.zip...
# Saved 2016-citibike-tripdata/12_December/201612-citibike-tripdata_1.csv to /content/working_dataset/2016-12.pkl
# Extracting and reading 2016-citibike-tripdata/11_November/201611-citibike-tripdata_2.csv from 2016-citibike-tripdata.zip...
# Saved 2016-citibike-tripdata/11_November/201611-citibike-tripdata_2.csv to /content/working_dataset/2016-11.pkl
# Extracting and reading 2016-citibike-tripdata/11_November/201611-citibike-tripdata_1.csv from 2016-citibike-tripdata.zip...
# Saved 2016-citibike-tripdata/11_November/201611-citibike-tripdata_1.csv to /content/working_dataset/2016-11.pkl
# Extracting and reading 2016-citibike-tripdata/7_July/201607-citibike-tripdata_2.csv from 2016-citibike-tripdata.zip...
# Saved 2016-citibike-tripdata/7_July/201607-citibike-tripdata_2.csv to /content/working_dataset/2016-07.pkl
# Extracting and reading 2016-citibike-tripdata/7_July/201607-citibike-tripdata_1.csv from 2016-citibike-tripdata.zip...
# Saved 2016-citibike-tripdata/7_July/201607-citibike-tripdata_1.csv to /content/working_dataset/2016-07.pkl
# Extracting and reading 2016-citibike-tripdata/10_October/201610-citibike-tripdata_1.csv from 2016-citibike-tripdata.zip...
# Saved 2016-citibike-tripdata/10_October/201610-citibike-tripdata_1.csv to /content/working_dataset/2016-10.pkl
# Extracting and reading 2016-citibike-tripdata/10_October/201610-citibike-tripdata_2.csv from 2016-citibike-tripdata.zip...
# Saved 2016-citibike-tripdata/10_October/201610-citibike-tripdata_2.csv to /content/working_dataset/2016-10.pkl
# Extracting and reading 2016-citibike-tripdata/9_September/201609-citibike-tripdata_1.csv from 2016-citibike-tripdata.zip...
# Saved 2016-citibike-tripdata/9_September/201609-citibike-tripdata_1.csv to /content/working_dataset/2016-09.pkl
# Extracting and reading 2016-citibike-tripdata/9_September/201609-citibike-tripdata_2.csv from 2016-citibike-tripdata.zip...
# Saved 2016-citibike-tripdata/9_September/201609-citibike-tripdata_2.csv to /content/working_dataset/2016-09.pkl
# Extracting and reading 2016-citibike-tripdata/8_August/201608-citibike-tripdata_2.csv from 2016-citibike-tripdata.zip...
# Saved 2016-citibike-tripdata/8_August/201608-citibike-tripdata_2.csv to /content/working_dataset/2016-08.pkl
# Extracting and reading 2016-citibike-tripdata/8_August/201608-citibike-tripdata_1.csv from 2016-citibike-tripdata.zip...
# Saved 2016-citibike-tripdata/8_August/201608-citibike-tripdata_1.csv to /content/working_dataset/2016-08.pkl
# Extracting and reading 2016-citibike-tripdata/6_June/201606-citibike-tripdata_1.csv from 2016-citibike-tripdata.zip...
# Saved 2016-citibike-tripdata/6_June/201606-citibike-tripdata_1.csv to /content/working_dataset/2016-06.pkl
# Extracting and reading 2016-citibike-tripdata/6_June/201606-citibike-tripdata_2.csv from 2016-citibike-tripdata.zip...
# Saved 2016-citibike-tripdata/6_June/201606-citibike-tripdata_2.csv to /content/working_dataset/2016-06.pkl
# Extracting and reading 2016-citibike-tripdata/3_March/201603-citibike-tripdata_1.csv from 2016-citibike-tripdata.zip...
# Saved 2016-citibike-tripdata/3_March/201603-citibike-tripdata_1.csv to /content/working_dataset/2016-03.pkl
# Extracting and reading 2016-citibike-tripdata/1_January/201601-citibike-tripdata_1.csv from 2016-citibike-tripdata.zip...
# Saved 2016-citibike-tripdata/1_January/201601-citibike-tripdata_1.csv to /content/working_dataset/2016-01.pkl
# Extracting and reading 2016-citibike-tripdata/2_February/201602-citibike-tripdata_1.csv from 2016-citibike-tripdata.zip...
# Saved 2016-citibike-tripdata/2_February/201602-citibike-tripdata_1.csv to /content/working_dataset/2016-02.pkl
# Extracting and reading 2016-citibike-tripdata/5_May/201605-citibike-tripdata_2.csv from 2016-citibike-tripdata.zip...
# Saved 2016-citibike-tripdata/5_May/201605-citibike-tripdata_2.csv to /content/working_dataset/2016-05.pkl
# Extracting and reading 2016-citibike-tripdata/5_May/201605-citibike-tripdata_1.csv from 2016-citibike-tripdata.zip...
# Saved 2016-citibike-tripdata/5_May/201605-citibike-tripdata_1.csv to /content/working_dataset/2016-05.pkl
# Processing 2015-citibike-tripdata.zip ... ['2015-citibike-tripdata/', '2015-citibike-tripdata/4_April/', '2015-citibike-tripdata/12_December/', '2015-citibike-tripdata/.DS_Store', '__MACOSX/2015-citibike-tripdata/._.DS_Store', '2015-citibike-tripdata/11_November/', '2015-citibike-tripdata/7_July/', '2015-citibike-tripdata/10_October/', '2015-citibike-tripdata/9_September/', '2015-citibike-tripdata/8_August/', '2015-citibike-tripdata/6_June/', '2015-citibike-tripdata/3_March/', '2015-citibike-tripdata/1_January/', '2015-citibike-tripdata/2_February/', '2015-citibike-tripdata/5_May/', '2015-citibike-tripdata/4_April/201504-citibike-tripdata_1.csv', '2015-citibike-tripdata/12_December/201512-citibike-tripdata_1.csv', '2015-citibike-tripdata/11_November/201511-citibike-tripdata_1.csv', '2015-citibike-tripdata/7_July/201507-citibike-tripdata_1.csv', '2015-citibike-tripdata/7_July/201507-citibike-tripdata_2.csv', '2015-citibike-tripdata/10_October/201510-citibike-tripdata_2.csv', '2015-citibike-tripdata/10_October/201510-citibike-tripdata_1.csv', '2015-citibike-tripdata/9_September/201509-citibike-tripdata_2.csv', '2015-citibike-tripdata/9_September/201509-citibike-tripdata_1.csv', '2015-citibike-tripdata/8_August/201508-citibike-tripdata_1.csv', '2015-citibike-tripdata/8_August/201508-citibike-tripdata_2.csv', '2015-citibike-tripdata/6_June/201506-citibike-tripdata_1.csv', '2015-citibike-tripdata/3_March/201503-citibike-tripdata_1.csv', '2015-citibike-tripdata/1_January/201501-citibike-tripdata_1.csv', '2015-citibike-tripdata/2_February/201502-citibike-tripdata_1.csv', '2015-citibike-tripdata/5_May/201505-citibike-tripdata_1.csv']
# Extracting and reading 2015-citibike-tripdata/4_April/201504-citibike-tripdata_1.csv from 2015-citibike-tripdata.zip...
# Saved 2015-citibike-tripdata/4_April/201504-citibike-tripdata_1.csv to /content/working_dataset/2015-04.pkl
# Extracting and reading 2015-citibike-tripdata/12_December/201512-citibike-tripdata_1.csv from 2015-citibike-tripdata.zip...
# Saved 2015-citibike-tripdata/12_December/201512-citibike-tripdata_1.csv to /content/working_dataset/2015-12.pkl
# Extracting and reading 2015-citibike-tripdata/11_November/201511-citibike-tripdata_1.csv from 2015-citibike-tripdata.zip...
# Saved 2015-citibike-tripdata/11_November/201511-citibike-tripdata_1.csv to /content/working_dataset/2015-11.pkl
# Extracting and reading 2015-citibike-tripdata/7_July/201507-citibike-tripdata_1.csv from 2015-citibike-tripdata.zip...
# Saved 2015-citibike-tripdata/7_July/201507-citibike-tripdata_1.csv to /content/working_dataset/2015-07.pkl
# Extracting and reading 2015-citibike-tripdata/7_July/201507-citibike-tripdata_2.csv from 2015-citibike-tripdata.zip...
# Saved 2015-citibike-tripdata/7_July/201507-citibike-tripdata_2.csv to /content/working_dataset/2015-07.pkl
# Extracting and reading 2015-citibike-tripdata/10_October/201510-citibike-tripdata_2.csv from 2015-citibike-tripdata.zip...
# Saved 2015-citibike-tripdata/10_October/201510-citibike-tripdata_2.csv to /content/working_dataset/2015-10.pkl
# Extracting and reading 2015-citibike-tripdata/10_October/201510-citibike-tripdata_1.csv from 2015-citibike-tripdata.zip...
# Saved 2015-citibike-tripdata/10_October/201510-citibike-tripdata_1.csv to /content/working_dataset/2015-10.pkl
# Extracting and reading 2015-citibike-tripdata/9_September/201509-citibike-tripdata_2.csv from 2015-citibike-tripdata.zip...
# Saved 2015-citibike-tripdata/9_September/201509-citibike-tripdata_2.csv to /content/working_dataset/2015-09.pkl
# Extracting and reading 2015-citibike-tripdata/9_September/201509-citibike-tripdata_1.csv from 2015-citibike-tripdata.zip...
# Saved 2015-citibike-tripdata/9_September/201509-citibike-tripdata_1.csv to /content/working_dataset/2015-09.pkl
# Extracting and reading 2015-citibike-tripdata/8_August/201508-citibike-tripdata_1.csv from 2015-citibike-tripdata.zip...
# Saved 2015-citibike-tripdata/8_August/201508-citibike-tripdata_1.csv to /content/working_dataset/2015-08.pkl
# Extracting and reading 2015-citibike-tripdata/8_August/201508-citibike-tripdata_2.csv from 2015-citibike-tripdata.zip...
# Saved 2015-citibike-tripdata/8_August/201508-citibike-tripdata_2.csv to /content/working_dataset/2015-08.pkl
# Extracting and reading 2015-citibike-tripdata/6_June/201506-citibike-tripdata_1.csv from 2015-citibike-tripdata.zip...
# Saved 2015-citibike-tripdata/6_June/201506-citibike-tripdata_1.csv to /content/working_dataset/2015-06.pkl
# Extracting and reading 2015-citibike-tripdata/3_March/201503-citibike-tripdata_1.csv from 2015-citibike-tripdata.zip...
# Saved 2015-citibike-tripdata/3_March/201503-citibike-tripdata_1.csv to /content/working_dataset/2015-03.pkl
# Extracting and reading 2015-citibike-tripdata/1_January/201501-citibike-tripdata_1.csv from 2015-citibike-tripdata.zip...
# Saved 2015-citibike-tripdata/1_January/201501-citibike-tripdata_1.csv to /content/working_dataset/2015-01.pkl
# Extracting and reading 2015-citibike-tripdata/2_February/201502-citibike-tripdata_1.csv from 2015-citibike-tripdata.zip...
# Saved 2015-citibike-tripdata/2_February/201502-citibike-tripdata_1.csv to /content/working_dataset/2015-02.pkl
# Extracting and reading 2015-citibike-tripdata/5_May/201505-citibike-tripdata_1.csv from 2015-citibike-tripdata.zip...
# Saved 2015-citibike-tripdata/5_May/201505-citibike-tripdata_1.csv to /content/working_dataset/2015-05.pkl
# Processing 2013-citibike-tripdata.zip ... ['2013-citibike-tripdata/', '2013-citibike-tripdata/4_April/', '2013-citibike-tripdata/12_December/', '2013-citibike-tripdata/.DS_Store', '__MACOSX/2013-citibike-tripdata/._.DS_Store', '2013-citibike-tripdata/201309-citibike-tripdata.csv', '__MACOSX/2013-citibike-tripdata/._201309-citibike-tripdata.csv', '2013-citibike-tripdata/11_November/', '2013-citibike-tripdata/7_July/', '2013-citibike-tripdata/201311-citibike-tripdata.csv', '__MACOSX/2013-citibike-tripdata/._201311-citibike-tripdata.csv', '2013-citibike-tripdata/201307-citibike-tripdata.csv', '__MACOSX/2013-citibike-tripdata/._201307-citibike-tripdata.csv', '2013-citibike-tripdata/10_October/', '2013-citibike-tripdata/9_September/', '2013-citibike-tripdata/8_August/', '2013-citibike-tripdata/6_June/', '2013-citibike-tripdata/3_March/', '2013-citibike-tripdata/201308-citibike-tripdata.csv', '__MACOSX/2013-citibike-tripdata/._201308-citibike-tripdata.csv', '2013-citibike-tripdata/1_January/', '2013-citibike-tripdata/201306-citibike-tripdata.csv', '__MACOSX/2013-citibike-tripdata/._201306-citibike-tripdata.csv', '2013-citibike-tripdata/201310-citibike-tripdata.csv', '__MACOSX/2013-citibike-tripdata/._201310-citibike-tripdata.csv', '2013-citibike-tripdata/2_February/', '2013-citibike-tripdata/5_May/', '2013-citibike-tripdata/201312-citibike-tripdata.csv', '__MACOSX/2013-citibike-tripdata/._201312-citibike-tripdata.csv', '2013-citibike-tripdata/12_December/201312-citibike-tripdata_1.csv', '2013-citibike-tripdata/11_November/201311-citibike-tripdata_1.csv', '2013-citibike-tripdata/7_July/201307-citibike-tripdata_1.csv', '2013-citibike-tripdata/10_October/201310-citibike-tripdata_2.csv', '2013-citibike-tripdata/10_October/201310-citibike-tripdata_1.csv', '2013-citibike-tripdata/9_September/201309-citibike-tripdata_2.csv', '2013-citibike-tripdata/9_September/201309-citibike-tripdata_1.csv', '2013-citibike-tripdata/8_August/201308-citibike-tripdata_1.csv', '2013-citibike-tripdata/8_August/201308-citibike-tripdata_2.csv', '2013-citibike-tripdata/6_June/201306-citibike-tripdata_1.csv', '__MACOSX/2013-citibike-tripdata/6_June/._201306-citibike-tripdata_1.csv']
# Extracting and reading 2013-citibike-tripdata/201309-citibike-tripdata.csv from 2013-citibike-tripdata.zip...
# Saved 2013-citibike-tripdata/201309-citibike-tripdata.csv to /content/working_dataset/2013-09.pkl
# Extracting and reading 2013-citibike-tripdata/201311-citibike-tripdata.csv from 2013-citibike-tripdata.zip...
# Saved 2013-citibike-tripdata/201311-citibike-tripdata.csv to /content/working_dataset/2013-11.pkl
# Extracting and reading 2013-citibike-tripdata/201307-citibike-tripdata.csv from 2013-citibike-tripdata.zip...
# Saved 2013-citibike-tripdata/201307-citibike-tripdata.csv to /content/working_dataset/2013-07.pkl
# Extracting and reading 2013-citibike-tripdata/201308-citibike-tripdata.csv from 2013-citibike-tripdata.zip...
# Saved 2013-citibike-tripdata/201308-citibike-tripdata.csv to /content/working_dataset/2013-08.pkl
# Extracting and reading 2013-citibike-tripdata/201306-citibike-tripdata.csv from 2013-citibike-tripdata.zip...
# Saved 2013-citibike-tripdata/201306-citibike-tripdata.csv to /content/working_dataset/2013-06.pkl
# Extracting and reading 2013-citibike-tripdata/201310-citibike-tripdata.csv from 2013-citibike-tripdata.zip...
# Saved 2013-citibike-tripdata/201310-citibike-tripdata.csv to /content/working_dataset/2013-10.pkl
# Extracting and reading 2013-citibike-tripdata/201312-citibike-tripdata.csv from 2013-citibike-tripdata.zip...
# Saved 2013-citibike-tripdata/201312-citibike-tripdata.csv to /content/working_dataset/2013-12.pkl
# Extracting and reading 2013-citibike-tripdata/12_December/201312-citibike-tripdata_1.csv from 2013-citibike-tripdata.zip...
# Saved 2013-citibike-tripdata/12_December/201312-citibike-tripdata_1.csv to /content/working_dataset/2013-12.pkl
# Extracting and reading 2013-citibike-tripdata/11_November/201311-citibike-tripdata_1.csv from 2013-citibike-tripdata.zip...
# Saved 2013-citibike-tripdata/11_November/201311-citibike-tripdata_1.csv to /content/working_dataset/2013-11.pkl
# Extracting and reading 2013-citibike-tripdata/7_July/201307-citibike-tripdata_1.csv from 2013-citibike-tripdata.zip...
# Saved 2013-citibike-tripdata/7_July/201307-citibike-tripdata_1.csv to /content/working_dataset/2013-07.pkl
# Extracting and reading 2013-citibike-tripdata/10_October/201310-citibike-tripdata_2.csv from 2013-citibike-tripdata.zip...
# Saved 2013-citibike-tripdata/10_October/201310-citibike-tripdata_2.csv to /content/working_dataset/2013-10.pkl
# Extracting and reading 2013-citibike-tripdata/10_October/201310-citibike-tripdata_1.csv from 2013-citibike-tripdata.zip...
# Saved 2013-citibike-tripdata/10_October/201310-citibike-tripdata_1.csv to /content/working_dataset/2013-10.pkl
# Extracting and reading 2013-citibike-tripdata/9_September/201309-citibike-tripdata_2.csv from 2013-citibike-tripdata.zip...
# Saved 2013-citibike-tripdata/9_September/201309-citibike-tripdata_2.csv to /content/working_dataset/2013-09.pkl
# Extracting and reading 2013-citibike-tripdata/9_September/201309-citibike-tripdata_1.csv from 2013-citibike-tripdata.zip...
# Saved 2013-citibike-tripdata/9_September/201309-citibike-tripdata_1.csv to /content/working_dataset/2013-09.pkl
# Extracting and reading 2013-citibike-tripdata/8_August/201308-citibike-tripdata_1.csv from 2013-citibike-tripdata.zip...
# Saved 2013-citibike-tripdata/8_August/201308-citibike-tripdata_1.csv to /content/working_dataset/2013-08.pkl
# Extracting and reading 2013-citibike-tripdata/8_August/201308-citibike-tripdata_2.csv from 2013-citibike-tripdata.zip...
# Saved 2013-citibike-tripdata/8_August/201308-citibike-tripdata_2.csv to /content/working_dataset/2013-08.pkl
# Extracting and reading 2013-citibike-tripdata/6_June/201306-citibike-tripdata_1.csv from 2013-citibike-tripdata.zip...
# Saved 2013-citibike-tripdata/6_June/201306-citibike-tripdata_1.csv to /content/working_dataset/2013-06.pkl

# %% [markdown]
# ## Check Results

# %%
import pandas as pd

debugging_dfs = []
for pickle_path in debugging_pickle_paths:
  debugging_dfs.append(pd.read_pickle(pickle_path) )

debugging_df = pd.concat(debugging_dfs, axis=0, ignore_index=True)

debugging_df.to_pickle("/content/debugging_dataset/debugging_dataset.pkl")

print(debugging_df.shape)
debugging_df.head()
# Out:
# (8081216, 15)
#    tripduration           starttime            stoptime  start_station_id  \
# 0           558 2014-04-01 00:00:07 2014-04-01 00:09:25                82
# 1           882 2014-04-01 00:00:20 2014-04-01 00:15:02               349
# 2           587 2014-04-01 00:00:25 2014-04-01 00:10:12               293
# 3           355 2014-04-01 00:00:44 2014-04-01 00:06:39               539
# 4           524 2014-04-01 00:01:29 2014-04-01 00:10:13               459
#
#                start_station_name  start_station_latitude  \
# 0          St James Pl & Pearl St               40.711174
# 1         Rivington St & Ridge St               40.718502
# 2           Lafayette St & E 8 St               40.730287
# 3  Metropolitan Ave & Bedford Ave               40.715348
# 4                W 20 St & 11 Ave               40.746745
#
#    start_station_longitude  end_station_id         end_station_name  \
# 0               -74.000165            2008    Little West St & 1 Pl
# 1               -73.983299             312  Allen St & E Houston St
# 2               -73.990765             334          W 20 St & 7 Ave
# 3               -73.960241             282       Kent Ave & S 11 St
# 4               -74.007756             503       E 20 St & Park Ave
#
#    end_station_latitude  end_station_longitude  bikeid    usertype birth_year  \
# 0             40.705693             -74.016777   21062  Subscriber       1982
# 1             40.722055             -73.989111   20229  Subscriber       1988
# 2             40.742388             -73.997262   20922  Subscriber       1959
# 3             40.708273             -73.968341   20914  Subscriber       1981
# 4             40.738274             -73.987520   21051  Subscriber       1964
#
#    gender
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
# Opening all working datasets leads to kernel crashing, all available RAM used up

# import pandas as pd

# working_dfs = []
# for pickle_path in working_pickle_paths:
#   working_dfs.append(pd.read_pickle(pickle_path) )

# working_df = pd.concat(working_dfs, axis=0, ignore_index=True)
# print(working_df.shape)
# working_df.head()
